# %% [markdown]
# <a href="https://colab.research.google.com/github/youjin0512/study_data_analytics/blob/main/pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## pandas

# %% [markdown]
# ### DataFrame (데이터 프레임) = (Series + Series + ...) + column
# - 다(복합) 변수

# %% [markdown]
# #### DataFrame 생성

# %%
list = [3,4,5,6]
pd.DataFrame(list)  # DataFrame : class 생성자
# Out:
#    0
# 0  3
# 1  4
# 2  5
# 3  6

# %%
# pd.Series(list)

# %%
double_list = [
             [1000, '과자','2019-12-31','반품'],
             [2000, '음료', '2020-03-02', '정상'],
             [3000, '아이스크림', '2020-02-03','정상'],
             [1000,'과자','2019-12-31','반품']
            ]
pd.DataFrame(data=double_list)
# Out:
#       0      1           2   3
# 0  1000     과자  2019-12-31  반품
# 1  2000     음료  2020-03-02  정상
# 2  3000  아이스크림  2020-02-03  정상
# 3  1000     과자  2019-12-31  반품

# %%
double_columns = ['가격','종류','판매일자','반품여부']
pd.DataFrame(data=double_list, columns=double_columns)
# Out:
#      가격     종류        판매일자 반품여부
# 0  1000     과자  2019-12-31   반품
# 1  2000     음료  2020-03-02   정상
# 2  3000  아이스크림  2020-02-03   정상
# 3  1000     과자  2019-12-31   반품

# %% [markdown]
# #### 내용 확인

# %%
df_saledays = pd.DataFrame(data=double_list, columns=double_columns)
type(df_saledays), df_saledays.shape
# Out:
# (pandas.core.frame.DataFrame, (4, 4))

# %%
df_saledays.index, df_saledays.columns, df_saledays.values    # DataFrame 분해(분리)
# Out:
# (RangeIndex(start=0, stop=4, step=1),
#  Index(['가격', '종류', '판매일자', '반품여부'], dtype='object'),
#  array([[1000, '과자', '2019-12-31', '반품'],
#         [2000, '음료', '2020-03-02', '정상'],
#         [3000, '아이스크림', '2020-02-03', '정상'],
#         [1000, '과자', '2019-12-31', '반품']], dtype=object))

# %%
type(df_saledays.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# #### 간편 확인

# %%
df_saledays.head(2)   # df_saledays.tail(2)
# Out:
#      가격  종류        판매일자 반품여부
# 0  1000  과자  2019-12-31   반품
# 1  2000  음료  2020-03-02   정상

# %%
df_saledays[:2]   # 슬라이싱(slicing)
# Out:
#      가격  종류        판매일자 반품여부
# 0  1000  과자  2019-12-31   반품
# 1  2000  음료  2020-03-02   정상

# %%
df_saledays[:-2]   # 슬라이싱(slicing)
# Out:
#      가격  종류        판매일자 반품여부
# 0  1000  과자  2019-12-31   반품
# 1  2000  음료  2020-03-02   정상

# %% [markdown]
# #### 데이터 정보 확인

# %%
df_saledays.info()    # function임
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가격      4 non-null      int64
#  1   종류      4 non-null      object
#  2   판매일자    4 non-null      object
#  3   반품여부    4 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 256.0+ bytes

# %%
df_saledays.describe()    # 통계
# Out:
#                 가격
# count     4.000000
# mean   1750.000000
# std     957.427108
# min    1000.000000
# 25%    1000.000000
# 50%    1500.000000
# 75%    2250.000000
# max    3000.000000

# %%
df_saledays.columns    # space 들어가도 column 값에 포함되니 유의
# Out:
# Index(['가격', '종류', '판매일자', '반품여부'], dtype='object')

# %%
df_saledays['종류'].unique, df_saledays['반품여부'].unique()    # DataFrame은 series의 집합 --> 아래 출력도 seires로 표현됨
# Out:
# (<bound method Series.unique of 0       과자
#  1       음료
#  2    아이스크림
#  3       과자
#  Name: 종류, dtype: object>,
#  array(['반품', '정상'], dtype=object))

# %% [markdown]
# ### loading dataset from files

# %%
df_california_housing = pd.read_csv("sample_data/california_housing_test.csv")

# %%
df_california_housing.info()    # 아래 결과값은 '수치형'  ## 수치형(연속형)이냐, 범주형이냐
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df_california_housing[100:105]
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 100    -118.30     34.02                49.0       2120.0           483.0
# 101    -122.23     37.79                43.0       5963.0          1344.0
# 102    -121.31     38.62                31.0       3114.0           430.0
# 103    -117.25     32.80                35.0       2281.0           506.0
# 104    -118.26     33.99                36.0       2016.0           505.0
#
#      population  households  median_income  median_house_value
# 100      1522.0       416.0         1.8500            116800.0
# 101      4367.0      1231.0         2.1917            112800.0
# 102      1121.0       456.0         6.2440            240000.0
# 103      1005.0       496.0         4.2296            275000.0
# 104      1807.0       464.0         1.6901            103500.0

# %% [markdown]
# ### loading dataset

# %%
pd.read_csv("sample_data/california_housing_test.csv")
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...
